# %% [markdown]
# ## 1 - Run baseline
# In questo esperimento andrò a riprodurre a grandi linee la baseline con modelli di ml vanilla,
# usando solo RandomForestClassifier e LogisticRegression.
#
# I dataset processati si trovano nel path `/notebooks/data/processed` e verrà effettuato l'addestramento
# per tutti i corsi singolarmente ed infine per il dataset concatenato.
#
# Le metriche di valutazione sono salvate in csv al path `/notebooks/outputs/runs`, compresa la **PR_AUC**
# per paragone con i risultati del paper
#
# L'esperimento è riprodotto per diverse variabili di lag, i metodi helper si trovano in `/notebooks/utils/baseline_helpers.py`

# %%
import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

import sys
sys.path.append(os.path.abspath("../.."))
from utils.baseline_helpers import prepare_flattened_data, evaluate_model

import warnings
warnings.filterwarnings("ignore")

# %%
INPUT_DIR = "/notebooks/data/processed"
OUTPUT_DIR = "/notebooks/outputs/runs"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# %%
CLASSIFIERS = {
    'RandomForest': RandomForestClassifier(random_state=42, n_jobs=-1),
    'LogisticRegression': LogisticRegression(random_state=42, max_iter=1000, n_jobs=-1) 
}

# --- LA MODIFICA CHIAVE: Lista di orizzonti temporali ---
LAGS = [7, 14, 30, 60, 90]

for current_lag in LAGS:
    print(f"[LOG] Starting runs for LAG -> {current_lag}")
    
    results_list = []
    
    for file_name in os.listdir(INPUT_DIR):
        if not file_name.endswith('.csv'):
            continue
            
        file_path = os.path.join(INPUT_DIR, file_name)
        course_name = file_name.replace('processed_', '').replace('.csv', '')
        
        print(f"\n[LOG] Processing course: {course_name} (LAG={current_lag})")
        
        X, y, feature_names = prepare_flattened_data(file_path, lag=current_lag)
        print(f"\n[LOG] Shape input (Flattened): {X.shape}, Shape target: {y.shape}")
        
        # 2. Addestramento e Valutazione
        for algo_name, model in CLASSIFIERS.items():
            print(f"[LOG] Evaluating {algo_name}...")
            metrics = evaluate_model(algo_name, model, X, y, n_splits=10)
            
            if metrics is not None:
                result_row = {
                    'course': course_name,
                    'algorithm': algo_name,
                    'accuracy': round(metrics['accuracy'], 4),
                    'precision': round(metrics['precision'], 4),
                    'recall': round(metrics['recall'], 4),
                    'f1': round(metrics['f1'], 4),
                    'roc_auc': round(metrics['roc_auc'], 4),
                    'pr_auc': round(metrics['pr_auc'], 4)
                }
                results_list.append(result_row)
                
    if results_list:
        df_results = pd.DataFrame(results_list)
        output_csv = os.path.join(OUTPUT_DIR, f"baseline_flat_lag{current_lag}_metrics.csv")
        df_results.to_csv(output_csv, index=False)
        print(f"\n[SUCCEEDED] Saved results for LAG={current_lag} in {output_csv}")
    else:
        print(f"\n[WARNING] No results generated for LAG={current_lag}")
# Out:
# [LOG] Starting runs for LAG -> 7
#
# [LOG] Processing course: timeseries_13 (LAG=7)
#
# [LOG] Shape input (Flattened): (7, 679), Shape target: (7,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
#
# [LOG] Processing course: timeseries_2 (LAG=7)
#
# [LOG] Shape input (Flattened): (250, 679), Shape target: (250,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_11 (LAG=7)
#
# [LOG] Shape input (Flattened): (539, 679), Shape target: (539,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_7 (LAG=7)
#
# [LOG] Shape input (Flattened): (204, 679), Shape target: (204,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
#
# [LOG] Processing course: timeseries_4 (LAG=7)
#
# [LOG] Shape input (Flattened): (676, 679), Shape target: (676,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_3 (LAG=7)
#
# [LOG] Shape input (Flattened): (75, 679), Shape target: (75,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
#
# [LOG] Processing course: timeseries_5 (LAG=7)
#
# [LOG] Shape input (Flattened): (269, 679), Shape target: (269,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_1 (LAG=7)
#
# [LOG] Shape input (Flattened): (113, 679), Shape target: (113,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_6 (LAG=7)
#
# [LOG] Shape input (Flattened): (469, 679), Shape target: (469,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_8 (LAG=7)
#
# [LOG] Shape input (Flattened): (739, 679), Shape target: (739,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_12 (LAG=7)
#
# [LOG] Shape input (Flattened): (240, 679), Shape target: (240,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_10 (LAG=7)
#
# [LOG] Shape input (Flattened): (814, 679), Shape target: (814,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: all_timeseries (LAG=7)
#
# [LOG] Shape input (Flattened): (5156, 679), Shape target: (5156,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_9 (LAG=7)
#
# [LOG] Shape input (Flattened): (761, 679), Shape target: (761,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [SUCCEEDED] Saved results for LAG=7 in /notebooks/outputs/runs/baseline_flat_lag7_metrics.csv
# [LOG] Starting runs for LAG -> 14
#
# [LOG] Processing course: timeseries_13 (LAG=14)
#
# [LOG] Shape input (Flattened): (7, 1358), Shape target: (7,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
#
# [LOG] Processing course: timeseries_2 (LAG=14)
#
# [LOG] Shape input (Flattened): (250, 1358), Shape target: (250,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_11 (LAG=14)
#
# [LOG] Shape input (Flattened): (539, 1358), Shape target: (539,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LOG] Processing course: timeseries_7 (LAG=14)
#
# [LOG] Shape input (Flattened): (204, 1358), Shape target: (204,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
#
# [LOG] Processing course: timeseries_4 (LAG=14)
#
# [LOG] Shape input (Flattened): (676, 1358), Shape target: (676,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_3 (LAG=14)
#
# [LOG] Shape input (Flattened): (75, 1358), Shape target: (75,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
#
# [LOG] Processing course: timeseries_5 (LAG=14)
#
# [LOG] Shape input (Flattened): (269, 1358), Shape target: (269,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_1 (LAG=14)
#
# [LOG] Shape input (Flattened): (113, 1358), Shape target: (113,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_6 (LAG=14)
#
# [LOG] Shape input (Flattened): (469, 1358), Shape target: (469,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_8 (LAG=14)
#
# [LOG] Shape input (Flattened): (739, 1358), Shape target: (739,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_12 (LAG=14)
#
# [LOG] Shape input (Flattened): (240, 1358), Shape target: (240,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_10 (LAG=14)
#
# [LOG] Shape input (Flattened): (814, 1358), Shape target: (814,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: all_timeseries (LAG=14)
#
# [LOG] Shape input (Flattened): (5156, 1358), Shape target: (5156,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [LOG] Processing course: timeseries_9 (LAG=14)
#
# [LOG] Shape input (Flattened): (761, 1358), Shape target: (761,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [SUCCEEDED] Saved results for LAG=14 in /notebooks/outputs/runs/baseline_flat_lag14_metrics.csv
# [LOG] Starting runs for LAG -> 30
#
# [LOG] Processing course: timeseries_13 (LAG=30)
#
# [LOG] Shape input (Flattened): (7, 2910), Shape target: (7,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
#
# [LOG] Processing course: timeseries_2 (LAG=30)
#
# [LOG] Shape input (Flattened): (250, 2910), Shape target: (250,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_11 (LAG=30)
#
# [LOG] Shape input (Flattened): (539, 2910), Shape target: (539,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_7 (LAG=30)
#
# [LOG] Shape input (Flattened): (204, 2910), Shape target: (204,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
#
# [LOG] Processing course: timeseries_4 (LAG=30)
#
# [LOG] Shape input (Flattened): (676, 2910), Shape target: (676,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_3 (LAG=30)
#
# [LOG] Shape input (Flattened): (75, 2910), Shape target: (75,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
#
# [LOG] Processing course: timeseries_5 (LAG=30)
#
# [LOG] Shape input (Flattened): (269, 2910), Shape target: (269,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_1 (LAG=30)
#
# [LOG] Shape input (Flattened): (113, 2910), Shape target: (113,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_6 (LAG=30)
#
# [LOG] Shape input (Flattened): (469, 2910), Shape target: (469,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_8 (LAG=30)
#
# [LOG] Shape input (Flattened): (739, 2910), Shape target: (739,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_12 (LAG=30)
#
# [LOG] Shape input (Flattened): (240, 2910), Shape target: (240,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_10 (LAG=30)
#
# [LOG] Shape input (Flattened): (814, 2910), Shape target: (814,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: all_timeseries (LAG=30)
#
# [LOG] Shape input (Flattened): (5156, 2910), Shape target: (5156,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_9 (LAG=30)
#
# [LOG] Shape input (Flattened): (761, 2910), Shape target: (761,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [SUCCEEDED] Saved results for LAG=30 in /notebooks/outputs/runs/baseline_flat_lag30_metrics.csv
# [LOG] Starting runs for LAG -> 60
#
# [LOG] Processing course: timeseries_13 (LAG=60)
#
# [LOG] Shape input (Flattened): (7, 5820), Shape target: (7,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
#
# [LOG] Processing course: timeseries_2 (LAG=60)
#
# [LOG] Shape input (Flattened): (250, 5820), Shape target: (250,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_11 (LAG=60)
#
# [LOG] Shape input (Flattened): (539, 5820), Shape target: (539,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_7 (LAG=60)
#
# [LOG] Shape input (Flattened): (204, 5820), Shape target: (204,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
#
# [LOG] Processing course: timeseries_4 (LAG=60)
#
# [LOG] Shape input (Flattened): (676, 5820), Shape target: (676,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_3 (LAG=60)
#
# [LOG] Shape input (Flattened): (75, 5820), Shape target: (75,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
#
# [LOG] Processing course: timeseries_5 (LAG=60)
#
# [LOG] Shape input (Flattened): (269, 5820), Shape target: (269,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_1 (LAG=60)
#
# [LOG] Shape input (Flattened): (113, 5820), Shape target: (113,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_6 (LAG=60)
#
# [LOG] Shape input (Flattened): (469, 5820), Shape target: (469,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_8 (LAG=60)
#
# [LOG] Shape input (Flattened): (739, 5820), Shape target: (739,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_12 (LAG=60)
#
# [LOG] Shape input (Flattened): (240, 5820), Shape target: (240,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_10 (LAG=60)
#
# [LOG] Shape input (Flattened): (814, 5820), Shape target: (814,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: all_timeseries (LAG=60)
#
# [LOG] Shape input (Flattened): (5156, 5820), Shape target: (5156,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_9 (LAG=60)
#
# [LOG] Shape input (Flattened): (761, 5820), Shape target: (761,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [SUCCEEDED] Saved results for LAG=60 in /notebooks/outputs/runs/baseline_flat_lag60_metrics.csv
# [LOG] Starting runs for LAG -> 90
#
# [LOG] Processing course: timeseries_13 (LAG=90)
#
# [LOG] Shape input (Flattened): (7, 8730), Shape target: (7,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 3, 1: 4). Skipped.
#
# [LOG] Processing course: timeseries_2 (LAG=90)
#
# [LOG] Shape input (Flattened): (250, 8730), Shape target: (250,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_11 (LAG=90)
#
# [LOG] Shape input (Flattened): (539, 8730), Shape target: (539,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_7 (LAG=90)
#
# [LOG] Shape input (Flattened): (204, 8730), Shape target: (204,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 6, 1: 198). Skipped.
#
# [LOG] Processing course: timeseries_4 (LAG=90)
#
# [LOG] Shape input (Flattened): (676, 8730), Shape target: (676,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_3 (LAG=90)
#
# [LOG] Shape input (Flattened): (75, 8730), Shape target: (75,)
# [LOG] Evaluating RandomForest...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
# [LOG] Evaluating LogisticRegression...
# [WARNING] Classi sbilanciate (0: 1, 1: 74). Skipped.
#
# [LOG] Processing course: timeseries_5 (LAG=90)
#
# [LOG] Shape input (Flattened): (269, 8730), Shape target: (269,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_1 (LAG=90)
#
# [LOG] Shape input (Flattened): (113, 8730), Shape target: (113,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_6 (LAG=90)
#
# [LOG] Shape input (Flattened): (469, 8730), Shape target: (469,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_8 (LAG=90)
#
# [LOG] Shape input (Flattened): (739, 8730), Shape target: (739,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_12 (LAG=90)
#
# [LOG] Shape input (Flattened): (240, 8730), Shape target: (240,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_10 (LAG=90)
#
# [LOG] Shape input (Flattened): (814, 8730), Shape target: (814,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: all_timeseries (LAG=90)
#
# [LOG] Shape input (Flattened): (5156, 8730), Shape target: (5156,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [LOG] Processing course: timeseries_9 (LAG=90)
#
# [LOG] Shape input (Flattened): (761, 8730), Shape target: (761,)
# [LOG] Evaluating RandomForest...
# [LOG] Evaluating LogisticRegression...
#
# [SUCCEEDED] Saved results for LAG=90 in /notebooks/outputs/runs/baseline_flat_lag90_metrics.csv
